# %%
import pandas as pd

# %%
df=pd.read_csv('data_science_job.csv')

# %% [markdown]
# 1. Basic Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  18679 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  float64
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  training_hours          18392 non-null  float64
#  12  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.9+ MB

# %%
df.shape
# Out:
# (19158, 13)

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'training_hours', 'target'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=19158, step=1)

# %%
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                float64
# company_size               object
# company_type               object
# training_hours            float64
# target                    float64
# dtype: object

# %% [markdown]
# 2. Viewing and Sampling Data

# %%
df.head(5)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# 2             STEM         5.0          NaN             NaN            83.0
# 3  Business Degree         0.0          NaN         Pvt Ltd            52.0
# 4             STEM        20.0        50-99  Funded Startup             8.0
#
#    target
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0

# %%
df.tail(5)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline  experience company_size company_type  training_hours  \
# 19153       Humanities        14.0          NaN          NaN            42.0
# 19154             STEM        14.0          NaN          NaN            52.0
# 19155             STEM        20.0        50-99      Pvt Ltd            44.0
# 19156              NaN         0.0      500-999      Pvt Ltd            97.0
# 19157              NaN         2.0          NaN          NaN           127.0
#
#        target
# 19153     1.0
# 19154     1.0
# 19155     0.0
# 19156     0.0
# 19157     0.0

# %%
df.sample(5)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 16166        16603  city_114                   0.926   Male
# 9703         26392  city_160                   0.920   Male
# 10991         9818  city_114                   0.926   Male
# 8937         25233   city_21                   0.624    NaN
# 3106         21749  city_103                   0.920   Male
#
#            relevent_experience enrolled_university education_level  \
# 16166  Has relevent experience       no_enrollment        Graduate
# 9703   Has relevent experience       no_enrollment        Graduate
# 10991  Has relevent experience       no_enrollment        Graduate
# 8937   Has relevent experience       no_enrollment         Masters
# 3106   Has relevent experience       no_enrollment        Graduate
#
#       major_discipline  experience company_size         company_type  \
# 16166             Arts         3.0        10/49              Pvt Ltd
# 9703              STEM        11.0          <10       Funded Startup
# 10991             STEM        12.0          <10              Pvt Ltd
# 8937              STEM         0.0          <10  Early Stage Startup
# 3106              STEM        20.0      500-999              Pvt Ltd
#
#        training_hours  target
# 16166            20.0     0.0
# 9703             24.0     0.0
# 10991            24.0     0.0
# 8937            118.0     1.0
# 3106             26.0     0.0

# %% [markdown]
# 3. Summary Statistics

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index    experience  training_hours  \
# count  19158.000000            18679.000000  19093.000000    18392.000000
# mean   16875.358179                0.828951      9.928036       65.185787
# std     9616.292592                0.123334      6.505268       59.885626
# min        1.000000                0.448000      0.000000        1.000000
# 25%     8554.250000                0.740000      4.000000       23.000000
# 50%    16982.500000                0.903000      9.000000       47.000000
# 75%    25169.750000                0.920000     16.000000       88.000000
# max    33380.000000                0.949000     20.000000      336.000000
#
#              target
# count  19158.000000
# mean       0.249348
# std        0.432647
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.describe(include='all')
# Out:
#          enrollee_id      city  city_development_index gender  \
# count   19158.000000     19158            18679.000000  14650
# unique           NaN       123                     NaN      3
# top              NaN  city_103                     NaN   Male
# freq             NaN      4355                     NaN  13221
# mean    16875.358179       NaN                0.828951    NaN
# std      9616.292592       NaN                0.123334    NaN
# min         1.000000       NaN                0.448000    NaN
# 25%      8554.250000       NaN                0.740000    NaN
# 50%     16982.500000       NaN                0.903000    NaN
# 75%     25169.750000       NaN                0.920000    NaN
# max     33380.000000       NaN                0.949000    NaN
#
#             relevent_experience enrolled_university education_level  \
# count                     19158               18772           18698
# unique                        2                   3               5
# top     Has relevent experience       no_enrollment        Graduate
# freq                      13792               13817           11598
# mean                        NaN                 NaN             NaN
# std                         NaN                 NaN             NaN
# min                         NaN                 NaN             NaN
# 25%                         NaN                 NaN             NaN
# 50%                         NaN                 NaN             NaN
# 75%                         NaN                 NaN             NaN
# max                         NaN                 NaN             NaN
#
#        major_discipline    experience company_size company_type  \
# count             16345  19093.000000        13220        13018
# unique                6           NaN            8            6
# top                STEM           NaN        50-99      Pvt Ltd
# freq              14492           NaN         3083         9817
# mean                NaN      9.928036          NaN          NaN
# std                 NaN      6.505268          NaN          NaN
# min                 NaN      0.000000          NaN          NaN
# 25%                 NaN      4.000000          NaN          NaN
# 50%                 NaN      9.000000          NaN          NaN
# 75%                 NaN     16.000000          NaN          NaN
# max                 NaN     20.000000          NaN          NaN
#
#         training_hours        target
# count     18392.000000  19158.000000
# unique             NaN           NaN
# top                NaN           NaN
# freq               NaN           NaN
# mean         65.185787      0.249348
# std          59.885626      0.432647
# min           1.000000      0.000000
# 25%          23.000000      0.000000
# 50%          47.000000      0.000000
# 75%          88.000000      0.000000
# max         336.000000      1.000000

# %%
df.describe(include=['object'])
# Out:
#             city gender      relevent_experience enrolled_university  \
# count      19158  14650                    19158               18772
# unique       123      3                        2                   3
# top     city_103   Male  Has relevent experience       no_enrollment
# freq        4355  13221                    13792               13817
#
#        education_level major_discipline company_size company_type
# count            18698            16345        13220        13018
# unique               5                6            8            6
# top           Graduate             STEM        50-99      Pvt Ltd
# freq             11598            14492         3083         9817

# %%
df.count()
# Out:
# enrollee_id               19158
# city                      19158
# city_development_index    18679
# gender                    14650
# relevent_experience       19158
# enrolled_university       18772
# education_level           18698
# major_discipline          16345
# experience                19093
# company_size              13220
# company_type              13018
# training_hours            18392
# target                    19158
# dtype: int64

# %%
df.nunique()
# Out:
# enrollee_id               19158
# city                        123
# city_development_index       93
# gender                        3
# relevent_experience           2
# enrolled_university           3
# education_level               5
# major_discipline              6
# experience                   21
# company_size                  8
# company_type                  6
# training_hours              241
# target                        2
# dtype: int64

# %% [markdown]
# 4. Checking for Missing Values

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# enrollee_id               19158
# city                      19158
# city_development_index    18679
# gender                    14650
# relevent_experience       19158
# enrolled_university       18772
# education_level           18698
# major_discipline          16345
# experience                19093
# company_size              13220
# company_type              13018
# training_hours            18392
# target                    19158
# dtype: int64

# %% [markdown]
# 5. Identifying Duplicates

# %%
df.duplicated().sum()
# Out:
# 0
